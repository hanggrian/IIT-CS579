# %% [markdown]
# # Final project

# %% [markdown]
# # Generating data
#
# The presentation phase has generated the `areas.json` and `vehicles.json` files,
# containing the "L" train stations and the total number of vehicles in each area,
# respectively.

# %%
from os import makedirs

from colorama import Fore, Style
from pandas import DataFrame
from us.states import IL

from _lib import FRAME_COLUMNS, ACS_DIR, get_census, load_areas

SELECTED_YEARS = [2009, 2013, 2018, 2023]
SELECTED_TABLE = {'B08301_002E': 'Population with personal vehicle'}


def fetch_tracts(tracts, call_client, year, columns):
    frame = \
        DataFrame(
            call_client(get_census()).get(
                list(columns.keys()),
                geo={'for': 'tract:*', 'in': f'state:{IL.fips} county:031'},
                year=year,
            ),
        ).rename(columns=columns)
    return frame[frame['tract'].isin(tracts)] \
        [FRAME_COLUMNS + list(columns.values())].copy()


print(f'{Fore.YELLOW}Fetching ACS 5-Year Estimates...{Style.RESET_ALL}')
makedirs(ACS_DIR, exist_ok=True)

for area in load_areas():
    print(f'{Style.BRIGHT}{area.area}{Style.RESET_ALL}{'.' * (25 - len(area.area))} ', end='')
    for i, year in enumerate(SELECTED_YEARS):
        fetch_tracts(
            area.tracts,
            lambda census: census.acs5,
            year,
            SELECTED_TABLE,
        ).to_csv(f'{ACS_DIR}/{area.area.lower().replace(' ', '_')}_{year}.csv', index=False)
        if i < 3:
            print(f'{(i + 1) * 25}%... ', end='')
        else:
            print('100%')
print(f'{Fore.GREEN}Done.{Style.RESET_ALL}')
# Out:
# Fetching ACS 5-Year Estimates...
# Rogers Park.............. 25%... 50%... 75%... 100%
# West Ridge............... 25%... 50%... 75%... 100%
# Uptown................... 25%... 50%... 75%... 100%
# Lincoln Square........... 25%... 50%... 75%... 100%
# North Center............. 25%... 50%... 75%... 100%
# Lake View................ 25%... 50%... 75%... 100%
# Lincoln Park............. 25%... 50%... 75%... 100%
# Near North Side.......... 25%... 50%... 75%... 100%
# Edison Park.............. 25%... 50%... 75%... 100%
# Norwood Park............. 25%... 50%... 75%... 100%
# Jefferson Park........... 25%... 50%... 75%... 100%
# Forest Glen.............. 25%... 50%... 75%... 100%
# North Park............... 25%... 50%... 75%... 100%
# Albany Park.............. 25%... 50%... 75%... 100%
# Portage Park............. 25%... 50%... 75%... 100%
# Irving Park.............. 25%... 50%... 75%... 100%
# Dunning.................. 25%... 50%... 75%... 100%
# Montclare................ 25%... 50%... 75%... 100%
# Belmont Cragin........... 25%... 50%... 75%... 100%
# Hermosa.................. 25%... 50%... 75%... 100%
# Avondale................. 25%... 50%... 75%... 100%
# Logan Square............. 25%... 50%... 75%... 100%
# Humboldt Park............ 25%... 50%... 75%... 100%
# West Town................ 25%... 50%... 75%... 100%
# Austin................... 25%... 50%... 75%... 100%
# West Garfield Park....... 25%... 50%... 75%... 100%
# East Garfield Park....... 25%... 50%... 75%... 100%
# Near West Side........... 25%... 50%... 75%... 100%
# North Lawndale........... 25%... 50%... 75%... 100%
# South Lawndale........... 25%... 50%... 75%... 100%
# Lower West Side.......... 25%... 50%... 75%... 100%
# Loop..................... 25%... 50%... 75%... 100%
# Near South Side.......... 25%... 50%... 75%... 100%
# Armour Square............ 25%... 50%... 75%... 100%
# Douglas.................. 25%... 50%... 75%... 100%
# Oakland.................. 25%... 50%... 75%... 100%
# Fuller Park.............. 25%... 50%... 75%... 100%
# Grand Boulevard.......... 25%... 50%... 75%... 100%
# Kenwood.................. 25%... 50%... 75%... 100%
# Washington Park.......... 25%... 50%... 75%... 100%
# Hyde Park................ 25%... 50%... 75%... 100%
# Woodlawn................. 25%... 50%... 75%... 100%
# South Shore.............. 25%... 50%... 75%... 100%
# Chatham.................. 25%... 50%... 75%... 100%
# Avalon Park.............. 25%... 50%... 75%... 100%
# South Chicago............ 25%... 50%... 75%... 100%
# Burnside................. 25%... 50%... 75%... 100%
# Calumet Heights.......... 25%... 50%... 75%... 100%
# Roseland................. 25%... 50%... 75%... 100%
# Pullman.................. 25%... 50%... 75%... 100%
# South Deering............ 25%... 50%... 75%... 100%
# East Side................ 25%... 50%... 75%... 100%
# West Pullman............. 25%... 50%... 75%... 100%
# Riverdale................ 25%... 50%... 75%... 100%
# Hegewisch................ 25%... 50%... 75%... 100%
# Garfield Ridge........... 25%... 50%... 75%... 100%
# Archer Heights........... 25%... 50%... 75%... 100%
# Brighton Park............ 25%... 50%... 75%... 100%
# McKinley Park............ 25%... 50%... 75%... 100%
# Bridgeport............... 25%... 50%... 75%... 100%
# New City................. 25%... 50%... 75%... 100%
# West Elsdon.............. 25%... 50%... 75%... 100%
# Gage Park................ 25%... 50%... 75%... 100%
# Clearing................. 25%... 50%... 75%... 100%
# West Lawn................ 25%... 50%... 75%... 100%
# Chicago Lawn............. 25%... 50%... 75%... 100%
# West Englewood........... 25%... 50%... 75%... 100%
# Englewood................ 25%... 50%... 75%... 100%
# Greater Grand Crossing... 25%... 50%... 75%... 100%
# Ashburn.................. 25%... 50%... 75%... 100%
# Auburn Gresham........... 25%... 50%... 75%... 100%
# Beverly.................. 25%... 50%... 75%... 100%
# Washington Heights....... 25%... 50%... 75%... 100%
# Mount Greenwood.......... 25%... 50%... 75%... 100%
# Morgan Park.............. 25%... 50%... 75%... 100%
# O'Hare................... 25%... 50%... 75%... 100%
# Edgewater................ 25%... 50%... 75%... 100%
# Done.

# %%
from os import makedirs

from colorama import Fore, Style
from pandas import DataFrame
from us.states import IL

from _lib import FRAME_COLUMNS, DECENNIAL_DIR, get_census, load_areas

SELECTED_TABLE1 = {'P001001': 'Total population 2010'}
SELECTED_TABLE2 = {'P1_001N': 'Total population 2020'}


def fetch_tracts(tracts, call_client, year, columns):
    frame = \
        DataFrame(
            call_client(get_census()).get(
                list(columns.keys()),
                geo={'for': 'tract:*', 'in': f'state:{IL.fips} county:031'},
                year=year,
            ),
        ).rename(columns=columns)
    return frame[frame['tract'].isin(tracts)] \
        [FRAME_COLUMNS + list(columns.values())].copy()


print(f'{Fore.YELLOW}Fetching Decennial Data...{Style.RESET_ALL}')
makedirs(DECENNIAL_DIR, exist_ok=True)

for area in load_areas():
    print(f'{Style.BRIGHT}{area.area}{Style.RESET_ALL}{'.' * (25 - len(area.area))} ', end='')
    fetch_tracts(
        area.tracts,
        lambda census: census.sf1,
        2010,
        SELECTED_TABLE1,
    ).to_csv(f'{DECENNIAL_DIR}/{area.area.lower().replace(' ', '_')}_2010.csv', index=False)
    print('50%... ', end='')
    fetch_tracts(
        area.tracts,
        lambda census: census.pl,
        2020,
        SELECTED_TABLE2,
    ).to_csv(f'{DECENNIAL_DIR}/{area.area.lower().replace(' ', '_')}_2020.csv', index=False)
    print('100%')
print(f'{Fore.GREEN}Done.{Style.RESET_ALL}')
# Out:
# Fetching Decennial Data...
# Rogers Park.............. 50%... 100%
# West Ridge............... 50%... 100%
# Uptown................... 50%... 100%
# Lincoln Square........... 50%... 100%
# North Center............. 50%... 100%
# Lake View................ 50%... 100%
# Lincoln Park............. 50%... 100%
# Near North Side.......... 50%... 100%
# Edison Park.............. 50%... 100%
# Norwood Park............. 50%... 100%
# Jefferson Park........... 50%... 100%
# Forest Glen.............. 50%... 100%
# North Park............... 50%... 100%
# Albany Park.............. 50%... 100%
# Portage Park............. 50%... 100%
# Irving Park.............. 50%... 100%
# Dunning.................. 50%... 100%
# Montclare................ 50%... 100%
# Belmont Cragin........... 50%... 100%
# Hermosa.................. 50%... 100%
# Avondale................. 50%... 100%
# Logan Square............. 50%... 100%
# Humboldt Park............ 50%... 100%
# West Town................ 50%... 100%
# Austin................... 50%... 100%
# West Garfield Park....... 50%... 100%
# East Garfield Park....... 50%... 100%
# Near West Side........... 50%... 100%
# North Lawndale........... 50%... 100%
# South Lawndale........... 50%... 100%
# Lower West Side.......... 50%... 100%
# Loop..................... 50%... 100%
# Near South Side.......... 50%... 100%
# Armour Square............ 50%... 100%
# Douglas.................. 50%... 100%
# Oakland.................. 50%... 100%
# Fuller Park.............. 50%... 100%
# Grand Boulevard.......... 50%... 100%
# Kenwood.................. 50%... 100%
# Washington Park.......... 50%... 100%
# Hyde Park................ 50%... 100%
# Woodlawn................. 50%... 100%
# South Shore.............. 50%... 100%
# Chatham.................. 50%... 100%
# Avalon Park.............. 50%... 100%
# South Chicago............ 50%... 100%
# Burnside................. 50%... 100%
# Calumet Heights.......... 50%... 100%
# Roseland................. 50%... 100%
# Pullman.................. 50%... 100%
# South Deering............ 50%... 100%
# East Side................ 50%... 100%
# West Pullman............. 50%... 100%
# Riverdale................ 50%... 100%
# Hegewisch................ 50%... 100%
# Garfield Ridge........... 50%... 100%
# Archer Heights........... 50%... 100%
# Brighton Park............ 50%... 100%
# McKinley Park............ 50%... 100%
# Bridgeport............... 50%... 100%
# New City................. 50%... 100%
# West Elsdon.............. 50%... 100%
# Gage Park................ 50%... 100%
# Clearing................. 50%... 100%
# West Lawn................ 50%... 100%
# Chicago Lawn............. 50%... 100%
# West Englewood........... 50%... 100%
# Englewood................ 50%... 100%
# Greater Grand Crossing... 50%... 100%
# Ashburn.................. 50%... 100%
# Auburn Gresham........... 50%... 100%
# Beverly.................. 50%... 100%
# Washington Heights....... 50%... 100%
# Mount Greenwood.......... 50%... 100%
# Morgan Park.............. 50%... 100%
# O'Hare................... 50%... 100%
# Edgewater................ 50%... 100%
# Done.

# %% [markdown]
# # Printing statistics
#
# Compare vehicle ownership with population, the information are tabulated in the report.

# %%
import re
from glob import glob

from pandas import read_csv, DataFrame, concat

from _lib import DECENNIAL_DIR, YEAR_KEY, create_tract_lookup_table, REGION_KEY, ACS_DIR

TOTAL_POPULATION_KEY: str = 'Total population'
VEHICLE_OWNERSHIP_KEY: str = 'Vehicle ownership'

VEHICLE_COL = 'Population with personal vehicle'


def generic_data_loader(data_dir: str) -> list[DataFrame]:
    file_list = glob(f'{data_dir}/*.csv')
    frames = []
    pattern = re.compile(r'.*?(\d{4})\.csv')

    for file_path in file_list:
        f = read_csv(file_path)

        match = pattern.search(file_path)
        if not match: continue

        f[YEAR_KEY] = int(match.group(1))
        f['tract'] = f['tract'].astype(str).str.zfill(6)
        frames.append(
            f.merge(create_tract_lookup_table(), on='tract', how='left') \
                .dropna(subset=[REGION_KEY]),
        )
    return frames


def load_decennial() -> DataFrame:
    frames = []
    for f in generic_data_loader(DECENNIAL_DIR):
        if f.empty:
            continue
        f.rename(
            columns={
                next(
                    (col for col in f.columns if
                     'population' in col.lower() and str(f[YEAR_KEY].iloc[0]) in col),
                    None,
                ): TOTAL_POPULATION_KEY,
            },
            inplace=True,
        )
        f[TOTAL_POPULATION_KEY] = f[TOTAL_POPULATION_KEY].astype(float)
        frames.append(f[[REGION_KEY, YEAR_KEY, TOTAL_POPULATION_KEY]])
    return DataFrame(columns=[REGION_KEY, YEAR_KEY, TOTAL_POPULATION_KEY]) \
        if not frames \
        else concat(frames, ignore_index=True) \
        .groupby([REGION_KEY, YEAR_KEY])[TOTAL_POPULATION_KEY] \
        .sum() \
        .reset_index()


def load_acs() -> DataFrame:
    frames = []
    for f in generic_data_loader(ACS_DIR):
        if f.empty:
            continue
        f.rename(columns={VEHICLE_COL: VEHICLE_OWNERSHIP_KEY}, inplace=True)
        f[VEHICLE_OWNERSHIP_KEY] = f[VEHICLE_OWNERSHIP_KEY].astype(float)
        frames.append(f[[REGION_KEY, YEAR_KEY, VEHICLE_OWNERSHIP_KEY]])
    return DataFrame(columns=[REGION_KEY, YEAR_KEY, VEHICLE_OWNERSHIP_KEY]) \
        if not frames \
        else concat(frames, ignore_index=True) \
        .groupby([REGION_KEY, YEAR_KEY])[VEHICLE_OWNERSHIP_KEY] \
        .sum() \
        .reset_index()


frame = \
    load_decennial().merge(
        load_acs(),
        on=[REGION_KEY, YEAR_KEY],
        how='outer',
    ).sort_values(by=[REGION_KEY, YEAR_KEY])
frame[TOTAL_POPULATION_KEY] = frame[TOTAL_POPULATION_KEY].fillna(0).astype(int)
frame[VEHICLE_OWNERSHIP_KEY] = frame[VEHICLE_OWNERSHIP_KEY].fillna(0).astype(int)
print(frame.to_string(index=False))
# Out:
#             Region  Year  Total population  Vehicle ownership
#            Central  2009                 0              12355
#            Central  2010             86830                  0
#            Central  2013                 0              16749
#            Central  2018                 0              17516
#            Central  2020            149977                  0
#            Central  2023                 0              26517
#     Far North Side  2009                 0              97646
#     Far North Side  2010            487023                  0
#     Far North Side  2013                 0             153773
#     Far North Side  2018                 0             157462
#     Far North Side  2020            496376                  0
#     Far North Side  2023                 0             147586
# Far Southeast Side  2009                 0              43904
# Far Southeast Side  2010            197740                  0
# Far Southeast Side  2013                 0              44811
# Far Southeast Side  2018                 0              47967
# Far Southeast Side  2020            190616                  0
# Far Southeast Side  2023                 0              48363
# Far Southwest Side  2009                 0              44231
# Far Southwest Side  2010            177974                  0
# Far Southwest Side  2013                 0              53662
# Far Southwest Side  2018                 0              56500
# Far Southwest Side  2020            170873                  0
# Far Southwest Side  2023                 0              51245
#         North Side  2009                 0              74158
#         North Side  2010            249314                  0
#         North Side  2013                 0              71928
#         North Side  2018                 0              69001
#         North Side  2020            263286                  0
#         North Side  2023                 0              56717
#     Northwest Side  2009                 0              68047
#     Northwest Side  2010            258149                  0
#     Northwest Side  2013                 0              93131
#     Northwest Side  2018                 0              97977
#     Northwest Side  2020            255451                  0
#     Northwest Side  2023                 0              90038
#         South Side  2009                 0              36517
#         South Side  2010            180341                  0
#         South Side  2013                 0              35890
#         South Side  2018                 0              34794
#         South Side  2020            195665                  0
#         South Side  2023                 0              41012
#     Southwest Side  2009                 0              88419
#     Southwest Side  2010            338135                  0
#     Southwest Side  2013                 0              92583
#     Southwest Side  2018                 0              94005
#     Southwest Side  2020            337033                  0
#     Southwest Side  2023                 0             100237
#          West Side  2009                 0              82776
#          West Side  2010            361699                  0
#          West Side  2013                 0              84034
#          West Side  2018                 0              91051
#          West Side  2020            363453                  0
#          West Side  2023                 0              93118

# %%
from collections import Counter

from colorama import Fore, Style

from _lib import load_areas

station_counts = Counter()
for area in load_areas():
    station_count = len(area.stations) if area.stations else 0
    if area.region:
        station_counts[area.region] += station_count

print(f'{Fore.YELLOW}Station counts...{Style.RESET_ALL}')
[
    print(f'{region:18s}: {Style.BRIGHT}{count}{Style.RESET_ALL} ')
    for region, count in station_counts.most_common()
]
print(f'{Fore.GREEN}Done.{Style.RESET_ALL}')
# Out:
# Station counts...
# West Side         : 34
# Central           : 26
# Far North Side    : 22
# North Side        : 15
# South Side        : 14
# Southwest Side    : 8
# Northwest Side    : 3
# Far Southeast Side: 3
# Far Southwest Side: 0
# Done.
